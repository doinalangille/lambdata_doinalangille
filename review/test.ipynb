# %% [markdown]
# <a href="https://colab.research.google.com/github/jcs-lambda/lambdata_doinalangille/blob/master/review/test.ipynd" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -i https://test.pypi.org/simple/ lambdata-doinalangille
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import lambdata_doinalangille.df_utils as ld_util

# %%
dates = ld_util.pd.date_range(start='2017-01-01', end='2017-12-31', freq='W-WED')
dates = ld_util.pd.DataFrame(dates, columns=['Date'])
dates.head()
# Out:
#         Date
# 0 2017-01-04
# 1 2017-01-11
# 2 2017-01-18
# 3 2017-01-25
# 4 2017-02-01

# %%
from numpy.random import randint

# %%
dates['number'] = randint(25, 500, len(dates))
dates.head()
# Out:
#         Date  number
# 0 2017-01-04     187
# 1 2017-01-11      60
# 2 2017-01-18     153
# 3 2017-01-25     229
# 4 2017-02-01     202

# %%
ld_dates = ld_util.Dates(dates, 'Date')

# %%
ld_dates.date_split()
# Out:
#          Date  number  year  month  day
# 0  2017-01-04     187  2017      1    4
# 1  2017-01-11      60  2017      1   11
# 2  2017-01-18     153  2017      1   18
# 3  2017-01-25     229  2017      1   25
# 4  2017-02-01     202  2017      2    1
# 5  2017-02-08     122  2017      2    8
# 6  2017-02-15     355  2017      2   15
# 7  2017-02-22     368  2017      2   22
# 8  2017-03-01     326  2017      3    1
# 9  2017-03-08     228  2017      3    8
# 10 2017-03-15     389  2017      3   15
# 11 2017-03-22      28  2017      3   22
# 12 2017-03-29     447  2017      3   29
# 13 2017-04-05      62  2017      4    5
# 14 2017-04-12     141  2017      4   12
# 15 2017-04-19     441  2017      4   19
# 16 2017-04-26     281  2017      4   26
# 17 2017-05-03     310  2017      5    3
# 18 2017-05-10     237  2017      5   10
# 19 2017-05-17     119  2017      5   17
# 20 2017-05-24     367  2017      5   24
# 21 2017-05-31     124  2017      5   31
# ...

# %%
train, val, test = ld_dates.train_val_test()

# %%
train.shape, val.shape, test.shape
# Out:
# ((32, 5), (9, 5), (11, 5))

# %%
dates.shape
# Out:
# (52, 5)

# %%
train
# Out:
#          Date  number  year  month  day
# 24 2017-06-21     434  2017      6   21
# 2  2017-01-18     153  2017      1   18
# 16 2017-04-26     281  2017      4   26
# 0  2017-01-04     187  2017      1    4
# 49 2017-12-13     423  2017     12   13
# 25 2017-06-28      57  2017      6   28
# 22 2017-06-07     478  2017      6    7
# 11 2017-03-22      28  2017      3   22
# 20 2017-05-24     367  2017      5   24
# 51 2017-12-27     407  2017     12   27
# 8  2017-03-01     326  2017      3    1
# 40 2017-10-11     302  2017     10   11
# 37 2017-09-20     361  2017      9   20
# 9  2017-03-08     228  2017      3    8
# 26 2017-07-05     472  2017      7    5
# 48 2017-12-06     132  2017     12    6
# 39 2017-10-04      41  2017     10    4
# 6  2017-02-15     355  2017      2   15
# 10 2017-03-15     389  2017      3   15
# 42 2017-10-25     313  2017     10   25
# 34 2017-08-30     455  2017      8   30
# 7  2017-02-22     368  2017      2   22
# ...

# %%
dates2 = dates.copy()
dates2['Date2'] = dates2['Date']
dates2.head()
# Out:
#         Date  number  year  month  day      Date2
# 0 2017-01-04     187  2017      1    4 2017-01-04
# 1 2017-01-11      60  2017      1   11 2017-01-11
# 2 2017-01-18     153  2017      1   18 2017-01-18
# 3 2017-01-25     229  2017      1   25 2017-01-25
# 4 2017-02-01     202  2017      2    1 2017-02-01

# %%
ld_util.Dates(dates2, ['Date', 'Date2']).date_split()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-1e8be1b3ac44> in <module>()
# ----> 1 ld_util.Dates(dates2, ['Date', 'Date2']).date_split()
#
# /usr/local/lib/python3.6/dist-packages/lambdata_doinalangille/df_utils.py in date_split(self)
#      84         # Convert the date column to datetime format
#      85         self.data[self.column] = pd.to_datetime(
# ---> 86           self.data[self.column], infer_datetime_format=True)
#      87         # Extract components from date
#      88         self.data['year'] = self.data[self.column].dt.year
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ...
